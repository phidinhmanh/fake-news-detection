# %% [markdown]
# # 🎓 Fake News Detection — Training Pipeline
#
# **Mở notebook → Shift+Enter lần lượt → Xong!**
#
# - Cell 1: Tạo mock data (20 records)
# - Cell 2: Chạy training → lưu checkpoint tự động

# %%
# 📦 Tạo mock data (20 records: 10 train, 5 val, 5 test)
import sys

sys.path.insert(0, "..")

from data.create_mock_data import main as create_mock_data
create_mock_data()
print("\n✅ Mock data đã sẵn sàng!")
# Out:
# [OK] data\datasets\normalized\train.parquet: 10 samples
# [OK] data\datasets\normalized\val.parquet: 5 samples
# [OK] data\datasets\normalized\test.parquet: 5 samples
#
# [INFO] Total: 20 samples
#    Train: 10 (fake=4, real=6)
#    Val:   5 (fake=2, real=3)
#    Test:  5 (fake=2, real=3)
#
# ✅ Mock data đã sẵn sàng!

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))  # Thêm thư mục gốc của dự án vào đường dẫn

# %%
print(sys.path)
# Out:
# ['..', 'C:\\Users\\Manh\\AppData\\Roaming\\uv\\python\\cpython-3.13-windows-x86_64-none\\python313.zip', 'C:\\Users\\Manh\\AppData\\Roaming\\uv\\python\\cpython-3.13-windows-x86_64-none\\DLLs', 'C:\\Users\\Manh\\AppData\\Roaming\\uv\\python\\cpython-3.13-windows-x86_64-none\\Lib', 'C:\\Users\\Manh\\AppData\\Roaming\\uv\\python\\cpython-3.13-windows-x86_64-none', 'd:\\Work\\project UET\\fake-new-detection\\.venv', '', 'd:\\Work\\project UET\\fake-new-detection\\.venv\\Lib\\site-packages', 'd:\\Work\\project UET\\fake-new-detection']

# %%
# 🚀 TRAINING — Gọi train() là xong!
# Checkpoint sẽ được lưu tại models/checkpoints/

from model.train import train

# Để mặc định config (model/config.yaml) — không cần chỉnh gì
# Nếu muốn curriculum learning: train(use_curriculum=True)
model, trainer = train(
    config_path="../model/config.yaml",
    use_curriculum=False,
    epochs=3,
 )  # 3 epochs cho mock data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 9
#       4 from model.train import train
#       7 # Để mặc định config (model/config.yaml) — không cần chỉnh gì
#       8 # Nếu muốn curriculum learning: train(use_curriculum=True)
# ----> 9 model, trainer = train(use_curriculum=False, epochs=3)  # 3 epochs cho mock data
#
# File d:\Work\project UET\fake-new-detection\notebooks\..\model\train.py:646, in train(config_path, use_curriculum, epochs, batch_size)
#     632 def train(
#     633     config_path: str = "model/config.yaml",
#     634     use_curriculum: bool = False,
#     635     epochs: int | None = None,
#     636     batch_size: int | None = None,
#     637 ):
#     638     """Train model — gọi trực tiếp từ notebook.
#     639
#     640     Args:
#    (...)    644         batch_size: Override batch_size from config
#     645     """
# --> 646     config = load_config(Path(config_path))
#     648     if epochs:
#     649         config["training"]["epochs"] = epochs
#
# File d:\Work\project UET\fake-new-detection\notebooks\..\model\train.py:408, in load_config(config_path)
#     399 def load_config(config_path: Path) -> Dict[str, Any]:
#     400     """Load configuration from YAML file.
#     401
#     402     Args:
#    (...)    406         Configuration dictionary.
#     407     """
# --> 408     with open(config_path, "r", encoding="utf-8") as f:
#     409         config = yaml.safe_load(f)
#     410     return config
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model\\config.yaml'

# %% [markdown]
# ---
# ## 📊 Kết quả
#
# Sau khi training xong:
# - **Checkpoint**: `models/checkpoints/fake-news-epochXX-val_f1-X.XX.ckpt`
# - **Final model**: `models/final_model.pt`
# - **LoRA adapter**: `models/lora_adapter/`
